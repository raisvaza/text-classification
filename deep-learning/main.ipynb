# %% [markdown]
# # Deep Learning for Text Classification using Word2Vec

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import re
import nltk
import numpy as np
import gensim
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from tensorflow.python.keras import models, layers, backend as K

# %% [markdown]
# ## Import Data

# %%
train = pd.read_csv("../data_worthcheck/train.csv")
test = pd.read_csv("../data_worthcheck/test.csv")
dev = pd.read_csv("../data_worthcheck/dev.csv")

X_dev = dev['text_a'].values
y_dev = dev['label'].values

X_train = train['text_a'].values
y_train = train['label'].values

X_test = test['text_a'].values
y_test = test['label'].values

# %% [markdown]
# ## Functions

# %%
def clean_data(text):
    normal_tw = text
    normal_tw = text.lower()
    normal_tw = re.sub(r'\\x.{2}', '', normal_tw)
    normal_tw = re.sub(r'((www\.[^\s]*)|(https?://[^\s]*))', '', normal_tw)
    normal_tw = normal_tw.strip()
    normal_tw = re.sub(r'@[^\s]+', '', normal_tw)
    normal_tw = re.sub(r'#[^\s]+', '', normal_tw)
    normal_tw = re.sub(r'\d+', ' ', normal_tw) 
    normal_tw = re.sub(r'^nan$', '', normal_tw) 
    normal_tw = re.sub(r'[_]+', '', normal_tw)
    normal_tw =  re.sub(r'[Ã°Âã¯¹¢²ðƒâ]', '', normal_tw) 
    normal_regex = re.compile(r"(.)\1{1,}")
    normal_tw = normal_regex.sub(r"\1\1", normal_tw)
    normal_tw = re.sub(r'\s+', ' ', normal_tw)
    normal_tw = re.sub(r'[^\w\s]', '', normal_tw) 
    normal_tw = re.sub(r'[^\x00-\x7F\x80-\xFF\u0100-\u017F\u0180-\u024F\u1E00-\u1EFF]', '', normal_tw)
    
    return normal_tw

stopwords_list = set(StopWordRemoverFactory().get_stop_words())

def tokenize_text(text):
    return nltk.word_tokenize(text)

def remove_stopwords(tokenized_text):
    # token = nltk.word_tokenize(text)
    token_afterremoval = []
    for k in tokenized_text:
        if k not in stopwords_list: 
            token_afterremoval.append(k)

    str_clean = ' '.join(token_afterremoval)
    return token_afterremoval

def preprocess(text):
    processed_text = clean_data(text)
    # processed_text = processed_text.lower()
    processed_text = tokenize_text(processed_text)
    processed_text = remove_stopwords(processed_text)
    return processed_text

def find_max_length(data):
    max = len(data[0])
    index = 0
    for i in range(len(data)):
        if max < len(data[i]):
            max = len(data[i])
            
    return max

def pad_sequence(arr, max_length):
    for i in range(len(arr)):
        arr[i] = np.asarray(arr[i])
        for k in range(len(arr[i])):
            arr[i][k] = float(arr[i][k])
        for j in range(len(arr[i]), max_length):
            # arr[i].append(0.0)
            arr[i] = np.append(arr[i], 0.0)
            # np.concatenate(arr[i], np.array([0]))
    return arr

# %% [markdown]
# ## Preprocessing

# %%
for i in range(len(X_dev)):
    X_dev[i] = preprocess(X_dev[i])

for j in range(len(X_train)):
    X_train[j] = preprocess(X_train[j])

for k in range(len(X_test)):
    X_test[k] = preprocess(X_test[k])

# %% [markdown]
# ## Features Extraction

# %%
MAX_COLUMN_LENGTH = find_max_length(X_train)
MAX_COLUMN_LENGTH = 100
VECTOR_SIZE = 100

# %%
w2c = gensim.models.word2vec.Word2Vec(sentences=X_train, min_count=1, vector_size=VECTOR_SIZE)

for i in range(len(X_train)):
    for j in range(len(X_train[i])):
        X_train[i][j] = w2c.wv.key_to_index[X_train[i][j]]

X_train = pad_sequence(X_train, MAX_COLUMN_LENGTH)

dic_vocab = w2c.wv.key_to_index

embeddings = np.zeros((len(dic_vocab) + 1, VECTOR_SIZE))
# print(dic_vocab.items())
for word, idx in dic_vocab.items():
    # print(w2c.wv[word])
    try:
        embeddings[idx] =  w2c.wv[word]
    # if word not in model then skip and the row stays all 0s
    except:
        pass

# %%
# Out:
# {'corona': 0,
#  'nya': 1,
#  't': 2,
#  'co': 3,
#  'https': 4,
#  'yg': 5,
#  'covid': 6,
#  'virus': 7,
#  'depok': 8,
#  'psbb': 9,
#  'distancing': 10,
#  'orang': 11,
#  'ga': 12,
#  'indonesia': 13,
#  'aja': 14,
#  'presiden': 15,
#  'physical': 16,
#  'menkes': 17,
#  'normal': 18,
#  'gak': 19,
#  'jakarta': 20,
#  'masker': 21,
#  'new': 22,
#  'kalo': 23,
#  'pemerintah': 24,
#  'udah': 25,
#  'jokowi': 26,
#  'ku': 27,
#  'positif': 28,
#  'warga': 29,
#  'kena': 30,
#  'menteri': 31,
#  'kota': 32,
#  'rumah': 33,
#  'kesehatan': 34,
#  'masyarakat': 35,
#  'sih': 36,
#  'gy': 37,
#  'amp': 38,
#  'masuk': 39,
#  'negara': 40,
#  'gubernur': 41,
#  'semoga': 42,
#  'tp': 43,
#  'gue': 44,
#  'penyebaran': 45,
#  'pasien': 46,
#  'rakyat': 47,
#  'org': 48,
#  'dr': 49,
#  'pake': 50,
#  'ramadhan': 51,
#  'lt': 52,
#  'kerja': 53,
#  'pandemi': 54,
#  'provinsi': 55,
#  'dki': 56,
#  'bikin': 57,
#  'berita': 58,
#  'wabah': 59,
#  'tau': 60,
#  'takut': 61,
#  'salah': 62,
#  'banget': 63,
#  'gw': 64,
#  'bersatulawancovid': 65,
#  'gt': 66,
#  'anak': 67,
#  'jd': 68,
#  'sikm': 69,
#  'dah': 70,
#  'biar': 71,
#  'dgn': 72,
#  'ni': 73,
#  'jaga': 74,
#  'kebijakan': 75,
#  'nih': 76,
#  'pemprov': 77,
#  'tangan': 78,
#  'coronavirus': 79,
#  'jg': 80,
#  'emang': 81,
#  'tdk': 82,
#  'si': 83,
#  'bilang': 84,
#  'pas': 85,
#  'jalan': 86,
#  'protokol': 87,
#  'social': 88,
#  'a': 89,
#  'sakit': 90,
#  'udh': 91,
#  'istimewa': 92,
#  'd': 93,
#  'gitu': 94,
#  'gimana': 95,
#  'klo': 96,
#  'sampe': 97,
#  'sehat': 98,
#  'allah': 99,
#  'sembuh': 100,
#  'info': 101,
#  'krn': 102,
#  'lg': 103,
#  'hiburan': 104,
#  'daerah': 105,
#  'utk': 106,
#  'dunia': 107,
#  'mu': 108,
#  'makan': 109,
#  'ri': 110,
#  'sekolah': 111,
#  'gini': 112,
#  'lu': 113,
#  'jgn': 114,
#  'bener': 115,
#  'polri': 116,
#  'bgt': 117,
#  'panik': 118,
#  'penanganan': 119,
#  'jawa': 120,
#  'm': 121,
#  'gua': 122,
#  'tuh': 123,
#  'barat': 124,
#  'pakai': 125,
#  'i': 126,
#  'buka': 127,
#  'k': 128,
#  'n': 129,
#  'langsung': 130,
#  'uang': 131,
#  'pencegahan': 132,
#  'h': 133,
#  'jarak': 134,
#  'an': 135,
#  'wa': 136,
#  'na': 137,
#  'kayak': 138,
#  'iya': 139,
#  'karna': 140,
#  'meninggal': 141,
#  'lupa': 142,
#  'sdh': 143,
#  'hoaks': 144,
#  'hoax': 145,
#  'menerapkan': 146,
#  'g': 147,
#  'ayo': 148,
#  'e': 149,
#  'aman': 150,
#  'x': 151,
#  'mei': 152,
#  'w': 153,
#  'aniesbaswedan': 154,
#  'terkait': 155,
#  'langkah': 156,
#  'mas': 157,
#  'deh': 158,
#  'media': 159,
#  'gara': 160,
#  'tu': 161,
#  'hidup': 162,
#  'cegah': 163,
#  'disiplinpolahidupbaru': 164,
#  'in': 165,
#  'sosial': 166,
#  'ekonomi': 167,
#  'kali': 168,
#  'kehidupan': 169,
#  'data': 170,
#  'y': 171,
#  'beli': 172,
#  'via': 173,
#  'hati': 174,
#  'tatanan': 175,
#  'anies': 176,
#  'jam': 177,
#  'cuci': 178,
#  'coronavirusupdates': 179,
#  'liat': 180,
#  'selamat': 181,
#  'gk': 182,
#  's': 183,
#  'skrg': 184,
#  'pasar': 185,
#  'lockdown': 186,
#  'khilafah': 187,
#  'tinggal': 188,
#  'dirumahaja': 189,
#  'to': 190,
#  'mencegah': 191,
#  'tni': 192,
#  'rangka': 193,
#  'pusat': 194,
#  'indo': 195,
#  'himbauan': 196,
#  'mall': 197,
#  'kasih': 198,
#  'mati': 199,
#  'c': 200,
#  'baca': 201,
#  'u': 202,
#  'suka': 203,
#  'manusia': 204,
#  'pagi': 205,
#  'the': 206,
#  'tugas': 207,
#  'bantuan': 208,
#  'kaya': 209,
#  'sesuai': 210,
#  'pulang': 211,
#  'eh': 212,
#  'yaa': 213,
#  'pengen': 214,
#  'aturan': 215,
#  'obat': 216,
#  'tetep': 217,
#  'mah': 218,
#  'korban': 219,
#  'coba': 220,
#  'wilayah': 221,
#  'detikcom': 222,
#  'beliau': 223,
#  'mudik': 224,
#  'dlm': 225,
#  'cek': 226,
#  'kemarin': 227,
#  'minggu': 228,
#  'kampus': 229,
#  'tubuh': 230,
#  'joko': 231,
#  'hai': 232,
#  'ko': 233,
#  'blm': 234,
#  'kek': 235,
#  'dg': 236,
#  'rs': 237,
#  'desa': 238,
#  'surabaya': 239,
#  'widodo': 240,
#  'penyakit': 241,
#  'juni': 242,
#  'china': 243,
#  'wkwk': 244,
#  'ngomong': 245,
#  'me': 246,
#  'keluarga': 247,
#  'mohon': 248,
#  'pembatasan': 249,
#  'melaksanakan': 250,
#  'sm': 251,
#  'p': 252,
#  'b': 253,
#  'air': 254,
#  'dokter': 255,
#  'ngga': 256,
#  'negeri': 257,
#  'kondisi': 258,
#  'yuk': 259,
#  'stay': 260,
#  'lo': 261,
#  'trus': 262,
#  'dirumah': 263,
#  'temen': 264,
#  'online': 265,
#  'semangat': 266,
#  'video': 267,
#  'doang': 268,
#  'malam': 269,
#  'ka': 270,
#  'cepat': 271,
#  'sy': 272,
#  'main': 273,
#  'kabupaten': 274,
#  'polsek': 275,
#  'r': 276,
#  'kantor': 277,
#  'la': 278,
#  'kak': 279,
#  'penularan': 280,
#  'informasi': 281,
#  'surat': 282,
#  'cari': 283,
#  'mata': 284,
#  'menjaga': 285,
#  'and': 286,
#  'beda': 287,
#  'v': 288,
#  'ak': 289,
#  'terawan': 290,
#  'isu': 291,
#  'harga': 292,
#  'dom': 293,
#  'raya': 294,
#  'butuh': 295,
#  'bogor': 296,
#  'bekasi': 297,
#  'libur': 298,
#  'update': 299,
#  'medis': 300,
#  'susah': 301,
#  'o': 302,
#  'yah': 303,
#  'akibat': 304,
#  'lakukan': 305,
#  'no': 306,
#  'dkijakarta': 307,
#  'test': 308,
#  'wajib': 309,
#  'tutup': 310,
#  'terima': 311,
#  'maaf': 312,
#  'waspada': 313,
#  'mudah': 314,
#  'suhu': 315,
#  'abis': 316,
#  'menghadapi': 317,
#  'jkt': 318,
#  'pejuang': 319,
#  'ki': 320,
#  'rame': 321,
#  'jabar': 322,
#  'min': 323,
#  'belajar': 324,
#  'didukung': 325,
#  'teman': 326,
#  'negatif': 327,
#  'trending': 328,
#  'gratis': 329,
#  'hasil': 330,
#  'malang': 331,
#  'terkena': 332,
#  'bang': 333,
#  'minum': 334,
#  'stasiun': 335,
#  'aktivitas': 336,
#  'anggota': 337,
#  'nama': 338,
#  'ketemu': 339,
#  'l': 340,
#  'walikota': 341,
#  'kabar': 342,
#  'kl': 343,
#  'kegiatan': 344,
#  'kampung': 345,
#  'ama': 346,
#  'bs': 347,
#  'petugas': 348,
#  'berubah': 349,
#  'or': 350,
#  'disiplin': 351,
#  'emg': 352,
#  'cnnindonesia': 353,
#  'terinfeksi': 354,
#  'puasa': 355,
#  'tuhan': 356,
#  'kepala': 357,
#  'msh': 358,
#  'publik': 359,
#  'alhamdulillah': 360,
#  'pemkot': 361,
#  'kuliah': 362,
#  'mengatasi': 363,
#  'bu': 364,
#  'ah': 365,
#  'gmn': 366,
#  'mending': 367,
#  'lebaran': 368,
#  'penerapan': 369,
#  'selesai': 370,
#  'jatim': 371,
#  'korona': 372,
#  'isi': 373,
#  'timur': 374,
#  'patroli': 375,
#  'makanan': 376,
#  'malaysia': 377,
#  'antisipasi': 378,
#  'sabun': 379,
#  'pergi': 380,
#  'cepet': 381,
#  'kelar': 382,
#  'dibuka': 383,
#  'pd': 384,
#  'viruscorona': 385,
#  'april': 386,
#  'lawan': 387,
#  'wib': 388,
#  'polres': 389,
#  'bandung': 390,
#  'ir': 391,
#  'ntar': 392,
#  'loh': 393,
#  'serius': 394,
#  'newnormal': 395,
#  'pejabat': 396,
#  'enak': 397,
#  'menangani': 398,
#  'gejala': 399,
#  'bebas': 400,
#  'percaya': 401,
#  'bingung': 402,
#  'ttg': 403,
#  'f': 404,
#  'wni': 405,
#  'dapet': 406,
#  'mobil': 407,
#  'bawa': 408,
#  'sadar': 409,
#  'khusus': 410,
#  'foto': 411,
#  'tes': 412,
#  'nak': 413,
#  'terapkan': 414,
#  'sumber': 415,
#  'tim': 416,
#  'terjangkit': 417,
#  'hand': 418,
#  'percepatan': 419,
#  'jepang': 420,
#  'selatan': 421,
#  'memakai': 422,
#  'melawan': 423,
#  'pra': 424,
#  'ttp': 425,
#  'so': 426,
#  'suspect': 427,
#  'turun': 428,
#  'zarazettirazr': 429,
#  'istana': 430,
#  'dennysiregar': 431,
#  'do': 432,
#  'tidur': 433,
#  'tanggal': 434,
#  'pernyataan': 435,
#  'knp': 436,
#  'who': 437,
#  'kau': 438,
#  'alasan': 439,
#  'kemenkesri': 440,
#  'vaksin': 441,
#  'jogja': 442,
#  'lihat': 443,
#  'dampak': 444,
#  'ambil': 445,
#  'flu': 446,
#  'sembako': 447,
#  'collegemenfess': 448,
#  'ibadah': 449,
#  'id': 450,
#  'upaya': 451,
#  'hrs': 452,
#  'hukum': 453,
#  'gagal': 454,
#  'pemimpin': 455,
#  'nasional': 456,
#  'acara': 457,
#  'papua': 458,
#  'republik': 459,
#  'kemaren': 460,
#  'usaha': 461,
#  'polisi': 462,
#  'otak': 463,
#  'maret': 464,
#  'bersih': 465,
#  'risiko': 466,
#  'da': 467,
#  'asli': 468,
#  'q': 469,
#  'safe': 470,
#  'wkwkwk': 471,
#  'diperpanjang': 472,
#  'sanitizer': 473,
#  'is': 474,
#  'trs': 475,
#  'situasi': 476,
#  'aneh': 477,
#  'terdampak': 478,
#  'ukt': 479,
#  'anti': 480,
#  'salam': 481,
#  'dukung': 482,
#  'z': 483,
#  'darurat': 484,
#  'sedih': 485,
#  'doa': 486,
#  'masjid': 487,
#  'at': 488,
#  'ma': 489,
#  'gaada': 490,
#  'batuk': 491,
#  'deket': 492,
#  'mikir': 493,
#  'menyebar': 494,
#  'tenang': 495,
#  'cina': 496,
#  'gugus': 497,
#  'bank': 498,
#  'badan': 499,
#  'program': 500,
#  'dpr': 501,
#  'j': 502,
#  'siang': 503,
#  'habis': 504,
#  'hi': 505,
#  'disuruh': 506,
#  'parah': 507,
#  'news': 508,
#  'aamiin': 509,
#  'merah': 510,
#  'agama': 511,
#  'rantai': 512,
#  'duit': 513,
#  'paham': 514,
#  'menhub': 515,
#  'lbh': 516,
#  'of': 517,
#  'tindakan': 518,
#  'kartu': 519,
#  'coronabukaborokrezim': 520,
#  'bantu': 521,
#  'pelaksanaan': 522,
#  'twitter': 523,
#  'terpapar': 524,
#  'gabisa': 525,
#  'politik': 526,
#  'nonton': 527,
#  'ramai': 528,
#  'yo': 529,
#  'kendaraan': 530,
#  'spt': 531,
#  'angka': 532,
#  'giat': 533,
#  'mesti': 534,
#  'for': 535,
#  'gatau': 536,
#  'kematian': 537,
#  'membantu': 538,
#  'pesan': 539,
#  'bkn': 540,
#  'rp': 541,
#  'dana': 542,
#  'putih': 543,
#  'ditengah': 544,
#  'kuat': 545,
#  'keputusan': 546,
#  'dakwah': 547,
#  'ustadtengkuzul': 548,
#  'suara': 549,
#  'km': 550,
#  'komunikasi': 551,
#  'keramaian': 552,
#  'karantina': 553,
#  'bumi': 554,
#  'ditutup': 555,
#  'penuh': 556,
#  'btw': 557,
#  'viral': 558,
#  'mandiri': 559,
#  'kadrun': 560,
#  'kelas': 561,
#  'kwa': 562,
#  'peduli': 563,
#  'gaji': 564,
#  'tunggu': 565,
#  'mbak': 566,
#  'keniscayaan': 567,
#  'didu': 568,
#  'bayar': 569,
#  'ra': 570,
#  'om': 571,
#  'coronavirusindonesia': 572,
#  'anjir': 573,
#  'hilang': 574,
#  'je': 575,
#  'besok': 576,
#  'mendukung': 577,
#  'rapat': 578,
#  'pemeriksaan': 579,
#  'panas': 580,
#  'wuhan': 581,
#  'tsb': 582,
#  'youtube': 583,
#  'dpt': 584,
#  'pengecekan': 585,
#  'lho': 586,
#  'be': 587,
#  'tenaga': 588,
#  'suruh': 589,
#  'bumnsiaplawancorona': 590,
#  'bumn': 591,
#  'bentuk': 592,
#  'bagus': 593,
#  'mulu': 594,
#  'fakta': 595,
#  'memiliki': 596,
#  'muncul': 597,
#  'msaid': 598,
#  'divhumas': 599,
#  'bicara': 600,
#  'ganti': 601,
#  'sistem': 602,
#  'you': 603,
#  'dikit': 604,
#  'kemenkes': 605,
#  'cuman': 606,
#  'tingkat': 607,
#  'ngerti': 608,
#  'utama': 609,
#  'dri': 610,
#  'jumat': 611,
#  'de': 612,
#  'terbaik': 613,
#  'bnpb': 614,
#  'lucu': 615,
#  'contoh': 616,
#  'ramlirizal': 617,
#  'ngapain': 618,
#  'muka': 619,
#  'beneran': 620,
#  'fadlizon': 621,
#  'memutus': 622,
#  'potongan': 623,
#  'tv': 624,
#  'sbg': 625,
#  'nder': 626,
#  'ganjarpranowo': 627,
#  'amerika': 628,
#  'kangen': 629,
#  'kontak': 630,
#  'banjir': 631,
#  'kyk': 632,
#  'share': 633,
#  'tgl': 634,
#  'barang': 635,
#  'mencuci': 636,
#  'hebat': 637,
#  'peraturan': 638,
#  'akun': 639,
#  'bahas': 640,
#  'sibuk': 641,
#  'khawatir': 642,
#  'sosialisasi': 643,
#  'berdoa': 644,
#  'ye': 645,
#  'berani': 646,
#  'ngasih': 647,
#  'gegara': 648,
#  'mahal': 649,
#  'berskala': 650,
#  'bandara': 651,
#  'jual': 652,
#  'kab': 653,
#  'as': 654,
#  'bareng': 655,
#  'ketua': 656,
#  'sby': 657,
#  'hahaha': 658,
#  'dilarang': 659,
#  'alias': 660,
#  'sok': 661,
#  'yak': 662,
#  'prosedur': 663,
#  'islam': 664,
#  'tangerang': 665,
#  'hp': 666,
#  'kementerian': 667,
#  'wisata': 668,
#  'berlaku': 669,
#  'rajin': 670,
#  'tanggap': 671,
#  'apapun': 672,
#  'sayang': 673,
#  'santuy': 674,
#  'simak': 675,
#  'apa': 676,
#  'selasa': 677,
#  'untung': 678,
#  'keren': 679,
#  'motor': 680,
#  'rabu': 681,
#  'kereta': 682,
#  'sulit': 683,
#  'engga': 684,
#  'bahan': 685,
#  'support': 686,
#  'ahli': 687,
#  'lampung': 688,
#  'setuju': 689,
#  'nomor': 690,
#  'solusi': 691,
#  'kpd': 692,
#  'melanggar': 693,
#  'tetangga': 694,
#  'pki': 695,
#  'aplikasi': 696,
#  'subtanyarl': 697,
#  'kasian': 698,
#  'wfh': 699,
#  'arah': 700,
#  'ridwankamil': 701,
#  'heran': 702,
#  'bahaya': 703,
#  'stayathome': 704,
#  'maju': 705,
#  'jujur': 706,
#  'bali': 707,
#  'ikuti': 708,
#  'bahasa': 709,
#  'berhasil': 710,
#  'hari': 711,
#  'pdhl': 712,
#  'tpi': 713,
#  'home': 714,
#  'pendidikan': 715,
#  'sabar': 716,
#  'aceh': 717,
#  'mrk': 718,
#  'dibilang': 719,
#  'malu': 720,
#  'pos': 721,
#  'walkot': 722,
#  'berbahaya': 723,
#  'hehe': 724,
#  'dianggap': 725,
#  'goblok': 726,
#  'mantan': 727,
#  'pengunjung': 728,
#  'on': 729,
#  'bangsa': 730,
#  'cm': 731,
#  'duta': 732,
#  'mengikuti': 733,
#  'mundur': 734,
#  'biaya': 735,
#  'bencana': 736,
#  'kapasitas': 737,
#  'sumpah': 738,
#  'status': 739,
#  'senin': 740,
#  'ae': 741,
#  'null': 742,
#  'jubir': 743,
#  'sehari': 744,
#  'giliran': 745,
#  'kadang': 746,
#  'menyambut': 747,
#  'diterapkan': 748,
#  'era': 749,
#  'berjalan': 750,
#  'berharap': 751,
#  'standar': 752,
#  'korea': 753,
#  'it': 754,
#  'dikasih': 755,
#  'parno': 756,
#  'tujuan': 757,
#  'was': 758,
#  'titik': 759,
#  'judul': 760,
#  'kamis': 761,
#  'keselamatan': 762,
#  'jabodetabek': 763,
#  'belom': 764,
#  'pilih': 765,
#  'nanya': 766,
#  'aj': 767,
#  'penggunaan': 768,
#  'ribut': 769,
#  'my': 770,
#  'muslim': 771,
#  'duduk': 772,
#  'wajar': 773,
#  'gila': 774,
#  'malem': 775,
#  'sholat': 776,
#  'nunggu': 777,
#  'penumpang': 778,
#  'addiems': 779,
#  'he': 780,
#  'ba': 781,
#  'guys': 782,
#  'nambah': 783,
#  'mba': 784,
#  'ruang': 785,
#  'lokasi': 786,
#  'akbar': 787,
#  'musim': 788,
#  'urusan': 789,
#  'saudara': 790,
#  'solo': 791,
#  'resmi': 792,
#  'ilang': 793,
#  'kaga': 794,
#  'wali': 795,
#  'bro': 796,
#  'pt': 797,
#  'keras': 798,
#  'cc': 799,
#  'nongkrong': 800,
#  'bupati': 801,
#  'mahasiswa': 802,
#  'melindungi': 803,
#  'kenal': 804,
#  'piyuu': 805,
#  'karyawan': 806,
#  'siaga': 807,
#  'terimakasih': 808,
#  'we': 809,
#  'fokus': 810,
#  'sblm': 811,
#  'kes': 812,
#  'pola': 813,
#  'uda': 814,
#  'dok': 815,
#  'cerita': 816,
#  'ny': 817,
#  'dinas': 818,
#  'stoppaniklawancorona': 819,
#  'plus': 820,
#  'pariwisata': 821,
#  'up': 822,
#  'izin': 823,
#  'anggap': 824,
#  'rapid': 825,
#  'bodoh': 826,
#  'pribadi': 827,
#  'pelayanan': 828,
#  'sma': 829,
#  'masyaallah': 830,
#  'tertular': 831,
#  'lahir': 832,
#  'lawancovid': 833,
#  'sarana': 834,
#  'haha': 835,
#  'kudu': 836,
#  'sukses': 837,
#  'link': 838,
#  'lgsg': 839,
#  'mo': 840,
#  'krna': 841,
#  'apresiasi': 842,
#  'kebal': 843,
#  'udara': 844,
#  'umat': 845,
#  'alat': 846,
#  'semenjak': 847,
#  'berbeda': 848,
#  'masi': 849,
#  'efek': 850,
#  'juta': 851,
#  'pusing': 852,
#  'krl': 853,
#  'sepi': 854,
#  'lawanhoax': 855,
#  'ps': 856,
#  'kaget': 857,
#  'riau': 858,
#  'plis': 859,
#  'penjelasan': 860,
#  'ii': 861,
#  'pedagang': 862,
#  'byk': 863,
#  'tua': 864,
#  'but': 865,
#  'wkwkw': 866,
#  'baswedan': 867,
#  'laporan': 868,
#  'anggaran': 869,
#  'area': 870,
#  'pancasila': 871,
#  'repost': 872,
#  'anjing': 873,
#  'membagikan': 874,
#  'amin': 875,
#  'ss': 876,
#  'kuota': 877,
#  'perdana': 878,
#  'fisik': 879,
#  'swab': 880,
#  'bersatu': 881,
#  'gelombang': 882,
#  'kec': 883,
#  'neng': 884,
#  'toko': 885,
#  'pasal': 886,
#  'kagak': 887,
#  'personil': 888,
#  'kejadian': 889,
#  'dasar': 890,
#  'coronavirusupdate': 891,
#  'from': 892,
#  'kat': 893,
#  'heboh': 894,
#  'apd': 895,
#  'pemda': 896,
#  'layanan': 897,
#  'allahu': 898,
#  'ditambah': 899,
#  'lha': 900,
#  'ayah': 901,
#  'bpk': 902,
#  'sektor': 903,
#  'wakil': 904,
#  'geloraco': 905,
#  'pcr': 906,
#  'gaboleh': 907,
#  'pekerja': 908,
#  'gamau': 909,
#  'perusahaan': 910,
#  'please': 911,
#  'jualan': 912,
#  'hujan': 913,
#  'life': 914,
#  'asing': 915,
#  'kebanyakan': 916,
#  'beritaterkini': 917,
#  'hmm': 918,
#  'nyari': 919,
#  'mal': 920,
#  'ktp': 921,
#  'arahan': 922,
#  'bentar': 923,
#  'mengamankan': 924,
#  'hy': 925,
#  'netizen': 926,
#  'za': 927,
#  'point': 928,
#  'uu': 929,
#  'selengkapnya': 930,
#  'singapura': 931,
#  'berat': 932,
#  'nyebar': 933,
#  'bertambah': 934,
#  'terbuka': 935,
#  'jateng': 936,
#  'bhabinkamtibmas': 937,
#  'gpp': 938,
#  'semarang': 939,
#  'rencana': 940,
#  'gada': 941,
#  'ngeri': 942,
#  'alam': 943,
#  'wk': 944,
#  'istilah': 945,
#  'grgr': 946,
#  'abetpunx': 947,
#  'bangkalan': 948,
#  'daftar': 949,
#  'kebersihan': 950,
#  'bertahap': 951,
#  'grup': 952,
#  'liburan': 953,
#  'jaya': 954,
#  'bukti': 955,
#  'prabowo': 956,
#  'rasulullah': 957,
#  'ho': 958,
#  'perpanjang': 959,
#  'tukang': 960,
#  'belanja': 961,
#  'denger': 962,
#  'gapapa': 963,
#  'blg': 964,
#  'like': 965,
#  'menunggu': 966,
#  'ribu': 967,
#  'kompascom': 968,
#  'jaman': 969,
#  'pajak': 970,
#  'halo': 971,
#  'jajaran': 972,
#  'ditemukan': 973,
#  'bismillah': 974,
#  'kalah': 975,
#  'edukasi': 976,
#  'arti': 977,
#  'dinyatakan': 978,
#  'mandi': 979,
#  'gaya': 980,
#  'beroperasi': 981,
#  'ramadhanindonesiaistimewa': 982,
#  'perjalanan': 983,
#  'menerima': 984,
#  'don': 985,
#  'sore': 986,
#  'sia': 987,
#  'bersamalawancorona': 988,
#  'lancar': 989,
#  'syarat': 990,
#  'pemerintahan': 991,
#  'kmrn': 992,
#  'persiapan': 993,
#  'kapolri': 994,
#  'terbaru': 995,
#  'ha': 996,
#  'ta': 997,
#  'pdp': 998,
#  'happyramadhan': 999,
#  ...}

# %% [markdown]
# ## Text Classification

# %%
x_in = layers.Input(shape=(MAX_COLUMN_LENGTH,))
x = layers.Embedding(input_dim=embeddings.shape[0], 
                    output_dim=embeddings.shape[1], 
                    weights=[embeddings], 
                    input_length=MAX_COLUMN_LENGTH,
                    trainable=False) (x_in)

x = layers.LSTM(units=15, dropout=0.2, return_sequences=True)(x)
                         
x = layers.LSTM(units=15, dropout=0.2)(x)

x = layers.Dense(64, activation='relu')(x)
y_out = layers.Dense(2, activation='softmax')(x)

model = models.Model(x_in, y_out)
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam', metrics=['accuracy'])

model.summary()

dic_y_mapping = {n:label for n,label in enumerate(np.unique(y_train))}
print(dic_y_mapping)
inverse_dic = {v:k for k,v in dic_y_mapping.items()}
print(inverse_dic)
y = np.array([inverse_dic[y] for y in y_train])
print(y)

X_train = np.array([np.array(val) for val in X_train])

training = model.fit(x=X_train, y=y, batch_size=256, 
                     epochs=10, shuffle=True, verbose=0, 
                     validation_split=0.3)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 595)]             0
# _________________________________________________________________
# embedding (Embedding)        (None, 595, 300)          13387200
# _________________________________________________________________
# lstm (LSTM)                  (None, 595, 15)           18960
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 15)                1860
# _________________________________________________________________
# dense (Dense)                (None, 64)                1024
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 13,409,239
# Trainable params: 22,039
# Non-trainable params: 13,387,200
# _________________________________________________________________
# {0: 'no', 1: 'yes'}
# {'no': 0, 'yes': 1}
# [0 0 1 ... 0 0 0]

# %%
X_train
# Out:
# array([[5.4920e+03, 1.2700e+02, 5.2300e+02, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [1.5700e+02, 8.0500e+02, 5.7640e+03, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [1.4900e+02, 8.7600e+02, 1.1200e+02, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        ...,
#        [7.0000e+00, 0.0000e+00, 1.9451e+04, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [2.8400e+02, 1.9456e+04, 1.8800e+02, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [1.2600e+02, 2.8900e+02, 4.9100e+02, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00]])

# %%
# Out:
# array([array(['5492', 'dajal', 'ga', 'depok', 'bang'], dtype='<U5'),
#        array(['detikcom', 'untung', 'depok', 'masuk', 'wilayah', 'nya', 'ridwan',
#               'kamil', 'kalo', 'masuk', 'wilayah', 'nya', 'anis', 'abis', 'lu',
#               'bully', 'ama', 'buzzer', 'kolam'], dtype='<U8')                   ,
#        array(['df', 'dom', 'jakarta', 'depok', 'yg', 'gunain', 'vc', 'cabang',
#               'nya', 'cabang', 'yg', 'tercantum', 'pas', 'kesana', 'gabisa',
#               'bayar', 'pake', 'shopeepay'], dtype='<U9')                     ,
#        ...,
#        array(['terawan', 'menyebut', 'virus', 'corona', 'indonesia',
#               'terdeteksi', 'minggu', 'kemarin', 'mendengar', 'berita',
#               'pemerintah', 'langsung', 'pemeriksaan', 'covid', 'indonesia'],
#              dtype='<U11')                                                   ,
#        array(['realffk', 'buhari', 'can', 't', 'pronounce', 'corona', 'virus'],
#              dtype='<U9')                                                      ,
#        array(['hadapi', 'wabah', 'corona', 'pemuda', 'muhammadiyah',
#               'pemerintah', 'cegah', 'munculnya', 'kepanikan'], dtype='<U12')],
#       dtype=object)

# %%
for i in range(len(X_test)):
    for j in range(len(X_test[i])):
        X_test[i][j] = w2c.wv.key_to_index[X_test[i][j]]
X_test = pad_sequence(X_test, MAX_COLUMN_LENGTH)
X_test = np.array([np.array(val) for val in X_test])

predictions = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Kuliah\Semester VII\NLP\Tugas\Text Classification\src\deep-learning\main.ipynb Cell 15 in <module>
#       <a href='vscode-notebook-cell:/d%3A/Kuliah/Semester%20VII/NLP/Tugas/Text%20Classification/src/deep-learning/main.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> for i in range(len(X_test)):
#       <a href='vscode-notebook-cell:/d%3A/Kuliah/Semester%20VII/NLP/Tugas/Text%20Classification/src/deep-learning/main.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a>     for j in range(len(X_test[i])):
# ----> <a href='vscode-notebook-cell:/d%3A/Kuliah/Semester%20VII/NLP/Tugas/Text%20Classification/src/deep-learning/main.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a>         X_test[i][j] = w2c.wv.key_to_index[X_test[i][j]]
#       <a href='vscode-notebook-cell:/d%3A/Kuliah/Semester%20VII/NLP/Tugas/Text%20Classification/src/deep-learning/main.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> X_test = pad_sequence(X_test, MAX_COLUMN_LENGTH)
#       <a href='vscode-notebook-cell:/d%3A/Kuliah/Semester%20VII/NLP/Tugas/Text%20Classification/src/deep-learning/main.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> X_test = np.array([np.array(val) for val in X_test])
#
# KeyError: 'dajal'
